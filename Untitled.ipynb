# %%
#Create Rectangle class with attributes length and breadth and methods to find area and perimeter. 
#Compare two Rectangle objects by their area.
class rectangle:
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return self.length*self.breadth
    def peri(self):
         return 2*(self.length+self.breadth) 
l1=int(input("enter the length:"))
l2=int(input("enter the breadth:"))
r1=rectangle(l1,l2)
print("area of a rectangle:",r1.area())
print("perimeter of a rectangle:",r1.peri())
l3=int(input("enter the length:"))
l4=int(input("enter the breadth:"))
r2=rectangle(l3,l4)
print("area of a rectangle:",r2.area())
print("perimeter of a rectangle:",r2.peri())
if r1.area()>r2.area():
    print("rec1 is bigger:")
else:
    print("rect2 is bigger")
# Out:
# enter the length:4
# enter the breadth:5
# area of a rectangle: 20
# perimeter of a rectangle: 18
# enter the length:5
# enter the breadth:6
# area of a rectangle: 30
# perimeter of a rectangle: 22
# rect2 is bigger

# %%
class rec:
    def __init__(self,l,b):
        self.l=l
        self.b=b
    def area(self):
        return self.l*self.b
    def peri(self):
        return 2*(self.l+self.b)
l1=int(input("enter length:"))
b1=int(input("enter breadth"))
r1=rec(l1,b1)
print("area of rec:",r1.area())
print("perimeter of rec:",r1.peri())
l2=int(input("enter length:"))
b2=int(input("enter breadth"))
r2=rec(l2,b2)
print("area of rec2:",r2.area())
print("perimeter of rec2:",r2.peri())
if r1.area()>r2.area():
    print("rec 1 is bigger:")
else:
    print("rec 2 is bigger:")
# Out:
# enter length:4
# enter breadth2
# area of rec: 8
# perimeter of rec: 12
# enter length:2
# enter breadth8
# area of rec2: 16
# perimeter of rec2: 20
# rec 2 is bigger:

# %%
class rectangle:
    def rect(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return self.length*self.breadth
    def peri(self):
        return 2*self.length+self.breadth
l1=int(input("enter the length:"))
b1=int(input("enter the breadth:"))
r1=rectangle()
r1.rect(l1,b1)
print("enter the area of rectangle:",r1.area())
print("enter the perimeter of rectangle:",r1.peri())
l2=int(input("enter the length:"))
b2=int(input("enter the breadth:"))
r2=rectangle()
r2.rect(l2,b2)
print("enter the area of rectangle:",r2.area())
print("enter the perimeter of rectangle:",r2.peri())
if r1.area()>r2.area():
    print("rectangle 1 is bigger")
else:
    print("rectangle 2 is bigger")
# Out:
# enter the length:5
# enter the breadth:4
# enter the area of rectangle: 20
# enter the perimeter of rectangle: 14
# enter the length:5
# enter the breadth:6
# enter the area of rectangle: 30
# enter the perimeter of rectangle: 16
# rectangle 2 is bigger

# %% [markdown]
# ##

# %%
#BANK ACCOUNT
class bank:
    def __init__(self,acc_no,acc_name,type,balance):
        self.acc_no=acc_no
        self.acc_name=acc_name
        self.type=type
        self.balance=balance
    def deposit(self,amt):
        self.balance+=amt
        print("enter the amount deposit:",amt)
    def withdraw(self,amt):
        if amt<=self.balance:
            print("amount withdrawn:")
        else:
            print("insufficent balance:")
    def display(self):
        print("\n account no:",self.acc_no,
             "\n account name:",self.acc_name,
             "\n account type:",self.type,
             "\n account balance:",self.balance)
b = bank(
    int(input("account no:")),
    input("account name:"),
    input("account type:"),
    int(input("account balance:")))
while(1):
    print("\n1.deposit\n2.withdraw\n3.Display\n4.Exit")
    ch=int(input("Enter your choice:"))
    if ch==1:
        b.deposit(float(input("Amount:")))
    elif ch==2:
        b.withdraw(int(input("Amount:")))
    elif ch==3:
        b.display()
    else:
        print("Exting.......")
        break
# Out:
# account no:198
# account name:uh
# account type:jtf
# account balance:12
#
# 1.deposit
# 2.withdraw
# 3.Display
# 4.Exit
# Enter your choice:3
#
#  account no: 198
#  account name: uh
#  account type: jtf
#  account balance: 12
#
# 1.deposit
# 2.withdraw
# 3.Display
# 4.Exit
# Enter your choice:4
# Exting.......

# %%
class bank:
    def __init__(self,accno,accname,a_type,bala):
        self.accno=accno
        self.accname=accname
        self.a_type=a_type
        self.bala=bala
    def deposit(self,amt):
        self.bala += amt
        print("Amount Deposit:",amt)
    def withdraw(self,amt):
        if amt <= self.bala:
            self.bala-=amt
            
            print("Amount withdrw:",amt)
        else:
            print("insufficent balance:",amt)
    def display(self):
        print("\nAccount no:",self.accno,
             "\nAccount name:",self.accname,
             "\nAccount Type:",self.a_type,
             "\nAccount Balance:",self.bala)
b=bank(
    int(input("enter accno:")),
    input("accname:"),
    input("Account type:"),
    int(input("balance:")))
while(1):
    print("\n1.Deposit\n2.Withdraw\n3.Display\n4.Exit")
    ch=int(input("Enter your choice:"))
    if ch==1:
        b.deposit(int(input("Enter the amount deposit:")))
    elif ch==2:
        b.withdraw(int(input("enter your withdraw:")))
    elif ch==3:
        b.display()
    else:
        print("Exiting")
        break
# Out:
# enter accno:784
# accname:cfiugh
# Account type:dluig
# balance:1000
#
# 1.Deposit
# 2.Withdraw
# 3.Display
# 4.Exit
# Enter your choice:2
# enter your withdraw:500
# Amount withdrw: 500
#
# 1.Deposit
# 2.Withdraw
# 3.Display
# 4.Exit
# Enter your choice:3
#
# Account no: 784
# Account name: cfiugh
# Account Type: dluig
# Account Balance: 500
#
# 1.Deposit
# 2.Withdraw
# 3.Display
# 4.Exit
# Enter your choice:4
# Exiting

# %%
#publish
class publisher:
    def __init__(self,name):
        self.name=name
    def display(self):
        print("publisher name",self.name)
class book(publisher):
    def __init__(self,name,title,author):
        super().__init__(name)
        self.title=title
        self.author=author
    def display(self):
        super().display()
        print("book title:",self.title)
        print("book author:",self.author)
class python(book):
    def __init__(self,name,title,author,price,no_pages):
        super().__init__(name,title,author)
        self.price=price
        self.no_pages=no_pages
    def display(self):
        super().display()
        print("price:",self.price)
        print("no_pages",self.no_pages)
pub=input("Enter publisher name:")
tit=input("Enter title name:")
auth=input("Enter author name:")
pri=int(input("Enter price :"))
page=int(input("Enter page :"))
book=python(pub,tit,auth,pri,page)
print("\nBook Details")
book.display()
# Out:
# Enter publisher name:uyfg]
# Enter title name:tfyj
# Enter author name:tfuj
# Enter price :56
# Enter page :4
#
# Book Details
# publisher name uyfg]
# book title: tfyj
# book author: tfuj
# price: 56
# no_pages 4

# %%
class times:
    def __init__(self,h,m,s):
        self.h=h
        self.m=m
        self.s=s
    def display(self):
        print(self.h,self.m,self.s)
    def __add__(self,other):
        hh=self.h+other.h
        mm=self.m+other.m
        ss=self.s+other.s
        if ss>=60:
            mm+=ss//60
            ss=ss%60
        if mm>=60:
            hh+=mm//60
            mm=mm%60
        return times(hh,mm,ss)
   
ob1=times(int(input("Enter the hour 1:")),int(input("enter the minute 1:")),int(input("enter the second 1:")))
ob2=times(int(input("Enter the hour 2:")),int(input("enter the minute 2:")),int(input("enter the second 2:")))
ob3=ob1+ob2
ob3.display()
# Out:
# Enter the hour 1:2
# enter the minute 1:4
# enter the second 1:6
# Enter the hour 2:8
# enter the minute 2:6
# enter the second 2:4
# 10 10 10

# %%
class time:
    def __init__(self,h,m,s):
        self.h=h
        self.m=m
        self.s=s
    def display(self):
        print(self.h,self.m,self.s)
    def add (self,other):
        hh=self.h+other.h
        mm=self.m+other.m
        ss=self.s+other.s
        if ss>=60:
            mm+=ss//60
            ss=ss%60
        if mm>=60:
            hh+=mm//60
            mm=mm%60
        return times(h,m,s)
ob1=times(int(input("Enter the hour 1:")),int(input("enter the minute 1:")),int(input("enter the second 1:")))
ob2=times(int(input("Enter the hour 2:")),int(input("enter the minute 2:")),int(input("enter the second 2:")))
ob3=ob1+ob2
ob3.display()
# Out:
# Enter the hour 1:1
# enter the minute 1:1
# enter the second 1:1
# Enter the hour 2:1
# enter the minute 2:1
# enter the second 2:1
# 2 2 2

# %%
"""1. Create a class Rectangle with private attributes length and width. Overload ‘<’ operator to
compare the area of 2 rectangles. """
class Rectangle:
    def __init__(self, length, width):   # Correct constructor
        self.__length = length           # Private attributes
        self.__width = width

    def area(self):
        return self.__length * self.__width

    def __lt__(self, other):# Correct operator overload
       return self.area() < other.area()
l=int(input("enetr the length of first rectangle:"))
w=int(input("enetr the width of first rectangle:"))
l2=int(input("enetr the length of 2nd rectangle:"))
w2=int(input("enetr the width of 2nd rectangle:"))
r1 = Rectangle(l,w)
r2 = Rectangle(l2,w2)
if (r1<r2):
    print("rectangle 1 is bigger")
else:
    print("rectangle 2 is bigger")
# Out:
# enetr the length of first rectangle:2
# enetr the width of first rectangle:4
# enetr the length of 2nd rectangle:6
# enetr the width of 2nd rectangle:8
# rectangle 1 is bigger

# %%
class rectangle:
    def __init__(self,l)
